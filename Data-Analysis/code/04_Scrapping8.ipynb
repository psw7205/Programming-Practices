# %% [markdown]
# ## BeautifulSoup 사용 스크랩핑 - 이미지 다운로드

# %%
import os
import urllib.parse as rep
import urllib.request as req
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

# %%
# Header 정보 초기화
opener = req.build_opener()
# User-Agent 정보
opener.addheaders = [('User-agent', UserAgent().ie)]
# Header 정보 삽입
req.install_opener(opener)

# %%
# 네이버 이미지 기본 URL(크롬 개발자 도구)
base = "https://search.naver.com/search.naver?where=image&sm=tab_jum&query="

# 검색어 urlencode(),quote_plus() =>  + 공백을 '+' 기호로 변환
quote = rep.quote_plus("고양이")

# URL 완성
url = base + quote

# 요청 URL 확인
print('Request URL : {}'.format(url))

# Request
res = req.urlopen(url)
# Out:
# Request URL : https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B3%A0%EC%96%91%EC%9D%B4

# %%
# 이미지 저장 경로
savePath = "../output/temp/"

try:
    if not (os.path.isdir(savePath)):
        os.makedirs(os.path.join(savePath))
except OSError as e:
        print("folder creation failed!")
        print("folder name : {}".format(e.filename))
        raise RuntimeError('System Exit!')
else:
    print('folder is created!')
# Out:
# folder is created!

# %%
soup = BeautifulSoup(res, "html.parser")
img_list = soup.select("div.img_area > a.thumb._thumb > img")
print(img_list)
# Out:
# [<img alt="[인천 서구 동물병원] 고양이 발톱 빠짐 증상 알아보자! | 블로그" class="_img" data-height="391" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20161010_199%2Fgphealah_1476089489722TNNbw_PNG%2F%25B0%25ED%25BE%25E7%25C0%25CC_%25B9%25DF%25C5%25E9_%25BA%25FC%25C1%25FC_%25C1%25F5%25BB%25F3_1.PNG&amp;type=b400" data-width="586" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="안산고양이분양은 믿을수 있는 곳에서!!(송도고양이분양) | 블로그" class="_img" data-height="851" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxODEwMDZfNzkg%2FMDAxNTM4Nzk4NjE4NzMw.niTIscLCkrSNpCC3VM9GeMe3nsXfqa4RIAHPCxkVR-Ug.vwSEsVgcUQmEAcTfRDDzS6OU1F38W5As2NfbBn8iJWcg.PNG.zxsw22%2F%25B0%25ED%25BE%25E7%25C0%25CC_%252888%2529.png&amp;type=b400" data-width="1280" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="[역삼동동물병원] 샴고양이 | 블로그" class="_img" data-height="606" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20130801_223%2Fdm5547505_1375346846253CBRhK_JPEG%2F%25B0%25ED%25BE%25E7%25C0%25CC3.jpg&amp;type=b400" data-width="740" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="노르웨이숲 분양 ★ 캐터리 마포점 (오케이독마포점) 실시간 분양사진입니다~! | 블로그" class="_img" data-height="398" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20150919_90%2Fkimiyong88_1442646576744NAFqt_JPEG%2FB3%2595%258C4.JPG&amp;type=b400" data-width="573" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="[고양이 기르기] 키우기 전 알아야 할 Tip ! | 블로그" class="_img" data-height="370" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20160222_233%2Fj_dh1991_1456106505134qdUgn_JPEG%2FB1A9BFEE_B0EDBEE7C0CC_BBE7C1F8_BDBAC4DA%253FBDAC_C6FAB5E5_7.jpg&amp;type=b400" data-width="312" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="[귀여운 바탕화면] 고양이 배경화면 1600x1200 063.jpg | 블로그" class="_img" data-height="1200" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20110516_245%2Fwdr08100_1305554434686VIbsO_JPEG%2F%25B1%25CD%25BF%25A9%25BF%25EE_%25B9%25D9%25C5%25C1%25C8%25AD%25B8%25E9_%25B0%25ED%25BE%25E7%25C0%25CC_%25B9%25E8%25B0%25E6%25C8%25AD%25B8%25E9_1600x1200_063.jpg&amp;type=b400" data-width="1600" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="고양이 | 블로그" class="_img" data-height="303" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20150127_81%2Fkbkss888_1422334506849no8hj_JPEG%2FB1A94.JPG&amp;type=b400" data-width="243" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="펫 포포즈와 알아보는 고양이 종류와 고양이 품종 1탄♥  | 블로그" class="_img" data-height="900" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20160409_217%2Fpet4paws_14601824284815TIHS_JPEG%2F%25B0%25ED%25BE%25E7%25C0%25CC%25C7%25B0%25C1%25BE.jpg&amp;type=b400" data-width="720" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="새끼 고양이가 눈꼽이끼고 눈이 부으면??? | 포스트" class="_img" data-height="853" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fpost.phinf.naver.net%2FMjAxOTAxMDlfMjIz%2FMDAxNTQ3MDE4MjE1MDA3.pHzEFnirlmQbfUkjedlbYSNSx0oYWF7HElq-aDjumxEg.I_NCod9zYwt-2bay0EHtqtyHi-SbF1wOJv6OBlL7tWwg.JPEG%2FI2Ol-1H2y60nDJVOS6sMbO-QYCDU.jpg&amp;type=b400" data-width="1280" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>, <img alt="고양이의 썩은 미소...ㄷㄷ | 블로그" cl ...

# %%
# 이미지 번호를 붙여주면서 다운로드
for i, img_list in enumerate(img_list, 1):
    fullFileName = os.path.join(savePath + str(i) + '.jpg')
    req.urlretrieve(img_list['data-source'], fullFileName)

# %%
# 다운로드 완료 시 출력
print("download succeeded!")
# Out:
# download succeeded!
